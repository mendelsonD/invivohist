# %% [markdown]
# Goal: cortical surface with vertex-equivalence to fsLR32k in native volumetric space. \
# Can then apply stitching script to fuse hippocampal and cortical surfaces
#
#
# Input: native surface with arbitrary number of vertices [ideally can support other histology datasets like AHEAD]

# %%
import

# %%
# compute sulcal depth
